# %%
import pandas as pd
import matplotlib as plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df=pd.read_csv("GAFA Stock Prices.csv")

# %%
df.tail()
# Out:
#         Stock        Date         Open         High          Low        Close  \
# 19615  Amazon  16/04/2018  1445.000000  1447.000000  1427.479980  1441.500000
# 19616  Amazon  17/04/2018  1462.300049  1507.189941  1457.020020  1503.829956
# 19617  Amazon  18/04/2018  1514.650024  1533.800049  1504.109985  1527.839966
# 19618  Amazon  19/04/2018  1543.219971  1568.520020  1539.060059  1556.910034
# 19619  Amazon  20/04/2018  1561.199951  1561.199951  1516.089966  1527.489990
#
#          Adj Close     Volume
# 19615  1441.500000  2808600.0
# 19616  1503.829956  5114400.0
# 19617  1527.839966  5227500.0
# 19618  1556.910034  6523700.0
# 19619  1527.489990  5507400.0

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  19619.000000  19619.000000  19619.000000  19619.000000  19619.000000
# mean     144.426622    145.870057    142.852804    144.413105    142.758556
# std      235.327960    237.241513    233.124553    235.296632    235.977156
# min        0.198661      0.198661      0.196429      0.196429      0.008937
# 25%        1.691964      1.729642      1.660714      1.695715      0.923260
# 50%       45.349998     46.000000     44.610001     45.389999     40.439999
# 75%      177.799995    179.674995    176.035004    177.900002    177.885002
# max     1615.959961   1617.540039   1590.890015   1598.390015   1598.390015
#
#              Volume
# count  1.961900e+04
# mean   4.883658e+07
# std    7.262879e+07
# min    7.900000e+03
# 25%    6.123700e+06
# 50%    2.203550e+07
# 75%    6.117545e+07
# max    1.855410e+09

# %%
df[df.Open==df.Open.max()].Date
# Out:
# 19592    13/03/2018
# Name: Date, dtype: object

# %%
plt.figure(figsize=(5,5))   
sns.heatmap(df.corr(),annot=True)

# %%
x=list(df[df.Stock=="Google"].Date)
y=list(df[df.Stock=="Google"].Close) 
plt.figure(figsize=(15,15))   
plt.plot(x, y)

# %%
x=list(df[df.Stock=="Apple"].Date)
y=list(df[df.Stock=="Apple"].Close) 
plt.figure(figsize=(15,15))   
plt.plot(x, y)

# %%
x=list(df[df.Stock=="Facebook"].Date)
y=list(df[df.Stock=="Facebook"].Close) 
plt.figure(figsize=(15,15))   
plt.plot(x, y)

# %%
x=list(df[df.Stock=="Amazon"].Date)
y=list(df[df.Stock=="Amazon"].Close) 
plt.figure(figsize=(15,15))   
plt.plot(x, y)
